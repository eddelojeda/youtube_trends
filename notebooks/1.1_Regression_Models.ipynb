# %% [markdown]
# ## 1.1. Regression Models for Predicting Number of Views and Likes per Video

# %% [markdown]
# This notebook contains an exploration of the target variables in the datasets on  `data/processed/`.
#
# See [1.1 Regression Models](https://eddelojeda.github.io/youtube_trends/1.1_Regression_Models.html) to interact with the dynamic plots in this notebook.

# %%
import os
import joblib
import warnings
import numpy as np
import pandas as pd
import torch.nn as nn
import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go
from xgboost import XGBRegressor
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from youtube_trends.config import PROCESSED_DATA_DIR, MODELS_DIR
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

pio.renderers.default = 'notebook_connected'
warnings.filterwarnings('ignore')
# Out:
# 2025-05-26 02:39:10.144 | INFO     | youtube_trends.config:<module>:11 - PROJ_ROOT path is: C:\Users\eddel\OneDrive\Documents\MCD\AAA\youtube_trends\venv\src\youtube-trends

# %% [markdown]
# #### Preparing training, validation, and testing datasets

# %% [markdown]
# Loading processed datasets `df_train`, `df_val` and `df_test`.

# %%
df_train = pd.read_csv(PROCESSED_DATA_DIR / 'train_dataset.csv', low_memory=False)
df_val = pd.read_csv(PROCESSED_DATA_DIR / 'val_dataset.csv', low_memory=False)
df_test = pd.read_csv(PROCESSED_DATA_DIR / 'test_dataset.csv', low_memory=False)

# %%
print(df_train.shape)
print(df_val.shape)
print(df_test.shape)
# Out:
# (46337, 199)
# (7626, 199)
# (6736, 199)

# %% [markdown]
# Feature selection.

# %%
drop_cols = ['video_view_count', 'video_like_count', 'days_to_trend', 'video_published_at']

X_train = df_train.drop(columns=drop_cols)
X_val = df_val.drop(columns=drop_cols)
X_test = df_test.drop(columns=drop_cols)

# %% [markdown]
# Only numeric columns are maintained for regression models. If --translate=True was specified during dataset processing, the `video_title_translated` function is available for interpretation, but won't be considered in the models in this notebook.

# %%
X_train = X_train.select_dtypes(include=np.number)
X_val = X_val.select_dtypes(include=np.number)
X_test = X_test.select_dtypes(include=np.number)

# %%
X_train.describe()
# Out:
#        video_duration  video_comment_count  channel_view_count  \
# count    46337.000000         46337.000000        4.633700e+04
# mean      1012.372273          3836.278438        6.040277e+09
# std       2819.329071          8609.104544        1.578495e+10
# min         10.000000             0.000000        2.163470e+05
# 25%         36.000000           335.000000        2.397540e+08
# 50%        160.000000          1138.000000        1.181903e+09
# 75%        984.000000          3205.000000        4.687050e+09
# max      42901.000000         82964.000000        2.970556e+11
#
#        channel_subscriber_count  published_dayofweek  published_hour  \
# count              4.633700e+04         46337.000000    46337.000000
# mean               1.197975e+07             3.197898       12.679932
# std                3.989381e+07             1.958441        5.814503
# min                5.600000e+01             0.000000        0.000000
# 25%                6.100000e+05             1.000000        9.000000
# 50%                2.650000e+06             3.000000       13.000000
# 75%                1.090000e+07             5.000000       17.000000
# max                3.960000e+08             6.000000       23.000000
#
#        video_title_length  video_tag_count  sentiment_score  \
# count        46337.000000     46337.000000     46337.000000
# mean             9.143212         0.655329         0.049619
# std              4.036997         0.493445         0.281998
# min              1.000000         0.000000        -0.897900
# 25%              6.000000         0.000000         0.000000
# 50%              9.000000         1.000000         0.000000
# 75%             12.000000         1.000000         0.000000
# max             25.000000         4.000000         0.944600
#
#        sentiment_negative  ...    lang_pca_0    lang_pca_1    lang_pca_2  \
# count        46337.000000  ...  4.633700e+04  4.633700e+04  4.633700e+04
# mean             0.144204  ... -7.851132e-17 -3.680218e-17  1.242074e-17
# std              0.351301  ...  4.589096e-01  2.054438e-01  1.585670e-01
# min              0.000000  ... -8.912856e-01 -3.484205e-01 -2.960471e-01
# 25%              0.000000  ... -6.937320e-01  7.831350e-03  1.800121e-03
# 50%              0.000000  ...  2.746552e-01  7.831350e-03  1.800121e-03
# 75%              0.000000  ...  2.746552e-01  7.831350e-03  1.800121e-03
# max              1.000000  ...  2.746552e-01  8.052141e-01  8.589263e-01
#
#          lang_pca_3    lang_pca_4  video_category_pca_0  video_category_pca_1  \
# count  4.633700e+04  4.633700e+04          4.633700e+04          4.633700e+04
# mean  -3.291112e-17  3.649070e-17          2.576153e-17          4.968294e-17
# std    1.435839e-01  1.414110e-01          4.796688e-01          3.860894e-01
# min   -5.788040e-01 -5.823643e-01         -3.966943e-01         -7.042180e-01
# 25%    2.321304e-04 -2.709102e-04         -3.926991e-01         -7.191368e-03
# 50%    2.321304e-04 -2.709102e-04         -2.536230e-01         -2.479025e-03
# 75%    2.321304e-04 -2.709102e-04          7.745709e-01          2.370603e-03
# max    7.906126e-01  7.749721e-01          7.745709e-01          7.099129e-01
#
#        video_category_pca_2  video_category_pca_3  days_published
# count          4.633700e+04          4.633700e+04    46337.000000
# mean           2.453479e-17          2.085457e-17       21.900986
# std            3.538891e-01          3.258885e-01        4.506948
# min           -4.341486e-01         -6.524535e-01       13.000000
# 25%           -4.194579e-01         -3.912901e-02       18.000000
# 50%           -6.956865e-02         -1.005693e-02       23.000000
# 75%            1.999355e-01          1.919796e-02       25.000000
# max            6.165521e-01          7.542877e-01       29.000000
#
# [8 rows x 196 columns]

# %% [markdown]
# Standardization of the numeric features.

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

joblib.dump(scaler, MODELS_DIR / 'scaler_regression.pkl')
# Out:
# ['C:\\Users\\eddel\\OneDrive\\Documents\\MCD\\AAA\\youtube_trends\\venv\\src\\youtube-trends\\models\\scaler_regression.pkl']

# %% [markdown]
# #### Target features

# %%
y_train_dict = {'video_view_count': df_train['video_view_count'], 'video_like_count': df_train['video_like_count']}
y_val_dict = {'video_view_count': df_val['video_view_count'], 'video_like_count': df_val['video_like_count']}
y_test_dict = {'video_view_count': df_test['video_view_count'], 'video_like_count': df_test['video_like_count']}

# %% [markdown]
# **Note:** Since the number of likes per video is strongly correlated with the number of views, we'll assume an explicit relation of dependancy between these features; more specifically, that the number of likes depends on the number of views, being the likes less than or equal to the views. This assumption is based on the premise that YouTube counts any play of the video as a view, regardless of the time it was played. This assumption might not be entirely true, since YouTube counts views based on a combination of factors, including the number of times a video is watched, the duration of each view, and user interactions. While the exact algorithm is not disclosed, a view generally requires a viewer to watch a portion of the video, often a minimum of 30 seconds, and actively engage with the content.

# %%
X_train_like = np.concatenate([X_train_scaled, df_train[['video_view_count']].values], axis=1)
X_val_like = np.concatenate([X_val_scaled, df_val[['video_view_count']].values], axis=1)
X_test_like = np.concatenate([X_test_scaled, df_test[['video_view_count']].values], axis=1)

# %% [markdown]
# #### Regression models

# %% [markdown]
# To predict the number of views and likes we use the following regression models.

# %%
model_classes = {
    'Linear_Regression': LinearRegression,
    'Ridge': Ridge,
    'Lasso': Lasso,
    'Decision_Tree': DecisionTreeRegressor,
    'Random_Forest': RandomForestRegressor,
    'XGBoost': XGBRegressor
}

# %% [markdown]
# Training and visualization of predicted values ​​versus actual values.

# %%
results = {}
results_test = {}
n_target = 0

for name, ModelClass in model_classes.items():
    results[name] = {}
    results_test[name] = {}

    # video_view_count
    model_vv = ModelClass()
    model_vv.fit(X_train_scaled, y_train_dict['video_view_count'])
    y_pred_vv = model_vv.predict(X_val_scaled)
    mse_vv = mean_squared_error(y_val_dict['video_view_count'], y_pred_vv)
    r2_vv = r2_score(y_val_dict['video_view_count'], y_pred_vv)
    results[name]['video_view_count'] = {'MSE': mse_vv, 'R^2': r2_vv}
    joblib.dump(model_vv, MODELS_DIR /  f'{name}_views.pkl')

    # Evaluate on test set
    y_test_pred_vv = model_vv.predict(X_test_scaled)
    mse_test_vv = mean_squared_error(y_test_dict['video_view_count'], y_test_pred_vv)
    r2_test_vv = r2_score(y_test_dict['video_view_count'], y_test_pred_vv)
    results_test[name]['video_view_count'] = {'MSE': mse_test_vv, 'R^2': r2_test_vv}

    # video_like_count
    model_vl = ModelClass()
    model_vl.fit(X_train_like, y_train_dict['video_like_count'])
    y_pred_vl = model_vl.predict(X_val_like)
    mse_vl = mean_squared_error(y_val_dict['video_like_count'], y_pred_vl)
    r2_vl = r2_score(y_val_dict['video_like_count'], y_pred_vl)
    results[name]['video_like_count'] = {'MSE': mse_vl, 'R^2': r2_vl}
    joblib.dump(model_vl, MODELS_DIR / f'{name}_likes.pkl')

    # Evaluate on test set
    y_test_pred_vl = model_vl.predict(X_test_like)
    mse_test_vl = mean_squared_error(y_test_dict['video_like_count'], y_test_pred_vl)
    r2_test_vl = r2_score(y_test_dict['video_like_count'], y_test_pred_vl)
    results_test[name]['video_like_count'] = {'MSE': mse_test_vl, 'R^2': r2_test_vl}

    # --- Visualizations ---
    for target, y_pred, y_true in zip(['video_view_count', 'video_like_count'], [y_pred_vv, y_pred_vl], [y_val_dict['video_view_count'], y_val_dict['video_like_count']]):
        if n_target % 2 == 0:
            print(f'\nModel: {name}\n')
        fig = go.Figure()
        fig.add_trace(go.Scatter(x=y_true, y=y_pred, mode='markers', name='Predictions'))
        fig.add_trace(go.Scatter(x=y_true, y=y_true, mode='lines', name='Ideal'))
        fig.update_layout(
            title=f'{name} for {target} (Validation)',
            xaxis_title='True Values',
            yaxis_title='Predicted Values',
            template='plotly_white'
        )
        fig.show()

        filename = f'figure_{100+n_target}.html'
        filepath = os.path.join('iframe_figures', filename)
        fig.write_html(filepath)

        n_target += 1
# Out:
# Model: Linear_Regression
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="1b63a80e-f0e4-4139-98fb-31f5f941bb82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1b63a80e-f0e4-4139-98fb-31f5f941bb82")) {                    Plotly.newPlot(                        "1b63a80e-f0e4-4139-98fb-31f5f941bb82",                        [{"mode":"markers","name":"Predictions","x":{"dtype":"f8","bdata":"\u002fyQAAAAABwsPBAAAAAAADN8kAAAAAAoObyQAAAAADA+vJAAAAAALA08kAAAAAAAAnZQAAAAADA1dpAAAAAAABm2kAAAAAAQOPaQAAAAADA\...\...\...\...\...\u002fQQAAABD1aIFBAAAAAAStgEEAAACYu9uBQQAAAGAkZ4BBAAAAEPVogUEAAACgLDCAQQAAAAAErYBBAAAAIJoTfkEAAAAABK2AQQAAAPgjZ4BBAAAA0Ar1gEEAAACgLDCAQQAAAJi724FBAAAAAGjmKEEAAAAAzLopQQAAAADgqSdBAAAAAMjcDEEAAAAARgEuQQAAAAC8pSBBAAAAAD4\...\u002fbkpBAAAAgLIPU0EAAABA9VdTQQAAAIBKikVBAAAAQB7AU0EAAACAxFhLQQAAAADAduZAAAAAAGDC40AAAAAwvRx2QQAAAID4\\u002ftAAAAAAMDvBUEAAAAAiHAAQQAAAADQoP5AAAAAANhaBEEAAAAA2GsFQQAAAABgWQJBAAAAAIhHBkEAAAAAADwFQQAAAACETRJBAAAAAPCIB0EAAAAAMPgOQQAAAABISQlBAAAAALj7DEEAAAAAJHIQQQAAAADgR\\...\u002flbQQAAAIBlIl5BAAAAgJLpWEEAAAAgtYZgQQAAAABC911BAAAAgAc7YEEAAACAj5lcQQAAAICPmVxBAAAAQL8LYUEAAADAHeBfQQAAAEC\\u002fmJBAAAAgHnsaEEAAAAAhuNlQQAAAIAg92pBAAAAgAbIZ0EAAAAAYT1qQQAAAAAt\\...\u002f\...\u002fCZBAAAAAHImI0EAAAAAuJ8pQQAAAAAE0ChBAAAAANQBNUEAAAAAI+IzQQAAAAApiTdBAAAAAGBeOEEAAAAAZDs2QQAAAAA07TFBAAAAAEgRN0EAAAAARcc1QQAAAABE\u002fjdBAAAAAG+SNkEAAACAublzQQAAAKAUhnNBAAAAUEcNcEEAAABAtBxjQQAAAADbqHFBAAAA8BBfc0EAAAAgH8JyQQAAAEBWS1lBAAAAYD8uc0EAAAAwH\...\...\u002fEAAAADg\u002fVd0QQAAAHDnIX1BAAAAcOchfUEAAACYgeaAQQAAABBFP4NBAAAACEU\\...\u002fg0EAAADg\u002fVd0QQAAALAlXHRBAAAAkGcbeUEAAABw5yF9QQAAAMDNpoNBAAAAIEh0hEEAAABAfKJSQQAAAGC9O2pBAAAAsDBcdEEAAADIgeaAQQAAAHid7YNBAAAAEEU\...\...\u002fNUaQQAAAADcdSZBAAAAAJ+VMEEAAAAAn5UwQQAAAABWYzFBAAAAAMx1JkEAAAAA\u002fNUaQQAAAADSlzBBAAAAAMx1JkEAAAAAwe4xQQAAAAAKBi9BAAAAANIIL0EAAAAA\u002fNUaQQA ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="1ac05d1b-4eac-4447-be12-08aa0012ad26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1ac05d1b-4eac-4447-be12-08aa0012ad26")) {                    Plotly.newPlot(                        "1ac05d1b-4eac-4447-be12-08aa0012ad26",                        [{"mode":"markers","name":"Predictions","x":{"dtype":"f8","bdata":"AAAAAMBh6UAAAAAAiJoDQQAAAACAmgNBAAAAAEDgBUEAAAAAQL4FQQAAAABgHwVBAAAAALgYA0EAAAAA8BoAQQAAAAA44AVBAAAAAJCZAUEAAAAAgF0FQQAAAAD4ggJBAAAAADjYBEEAAAAAiHgEQQAAAADwggJBAAAAAAiTBUEAAAAAABsAQQAAAAAw4AVBAAAAAIB4BEEAAAAAuJkBQQAAAADg\...\u002f0AAAAAAwHLwQAAAAAAge\u002fhAAAAAABDpBUEAAAAAkHH0QAAAAABIvgZBAAAAAPBy8EAAAAAA4Nb\u002fQAAAAACge\u002fhAAAAAAKDX\u002f0AAAAAAQHL0QAAAAACQcvRAAAAAAICqAkEAAAAAYJgBQQAAAADI6QVBAAAAAOBc60AAAAAA0Lv7QAAAAACwu\u002ftAAAAAAKiYAUEAAAAAUJgBQQAAAABIqgJBAAAAAEBy8EAAAAAAGDwFQQAAAACIqgJBAAAAAPA7BUEAAAAAoJgBQQAAAABgqgJBAAAAAOBZ60AAAAAAWJgBQQAAAABQ1v9AAAAAAJCcA0EAAAAAwLz7QAAAAADwu\u002ftAAAAAALiFB0EAAAAAsLz7QAAAAAAo6QVBAAAAAGBy8EAAAAAAIOkFQQAAAABgcfRAAAAAAJicA0EAAAAAuJwDQQAAAADAevhAAAAAALCFB0EAAAAA8JwDQQAAAACQcfRAAAAAAEiqAkEAAAAA4HLwQAAAAACgWutAAAAAAMCFBEEAAAAAoHH0QAAAAAAA6QVBAAAAAAB7+EAAAAAAUNf\u002fQAAAAABQqgJBAAAAABjpBUEAAAAA0IUHQQAAAADA1v9AAAAAALBx9EAAAAAA8Lv7QAAAAAA4vgZBAAAAANBy8EAAAAAA+DsFQQAAAABYmAFBAAAAAECqAkEAAAAAoNb\u002fQAAAAADAhQdBAAAAAAjpBUEAAAAA+DsFQQAAAADQe\...\...\u002fJZAAAAAAIBD4kAAAAAAYJ\u002fiQAAAAABgr+JAAAAAAEBD4kAAAAAAAI3iQAAAAABgQ+JAAAAAAADgsUAAAAAAACuxQAAAAAAAK7FAAAAAAADMsUAAAAAAAPyxQAAAAAAAnbFAAAAAAADosUAAAAAAAJ2xQAAAAAAA87FAAAAAAAABskAAAAAAwG3SQAAAAAAAatJAAAAAAMBO0kAAAAAAgGzSQAAAAADATtJAAAAAAABt0kAAAAAAAGrSQAAAAABAbdJAAAAAACD\u002f6EAAAAAAwMHlQAAAAADgpudAAAAAACAS60AAAAAAABLrQAAAAADgOepAAAAAAIDB5UAAAAAAQP\u002foQAAAAAAgp+dAAAAAAKA56kAAAAAAIMLlQAAAAABgPONAAAAAACDN40AAAAAAgMbmQAAAAAAAO+VAAAAAAIA\u002f50AAAAAAQJTmQAAAAAAgT+ZAAAAAAKBP50AAAAAA4DrlQAAAAADAEudAAAAAAIDG5kAAAAAAwPzlQAAAAABg\u002fuZAAAAAAIAj50AAAAAAYP7mQAAAAAAAzeNAAAAAAKDM40AAAAAAYOjmQAAAAACg\...\u002fXQAAAAABAv9dAAAAAAADEpUAAAAAAABiiQAAAAABQXQhBAAAAAHAj\u002fEAAAAAAaKcGQQAAAADwUQdBAAAAAEBvCUEAAAAAyPAFQQAAAADoXAhBAAAAABAi\u002fEAAAAAAyPAFQQAAAADAIvxAAAAAAOhRB0EAAAAAACP8QAAAAACApwZBAAAAALDwBUEAAAAAIF0IQQAAAADA8AVBAAAAAOAh\u002fEAAAAAAGFIHQQAAAACYbwlBAAAAAPBcCEEAAAAAeLoEQQAAAAAQ5fFAAAAAANhvAkEAAAAAWF0IQQAAAACIbwlBAAAAAEhdCEEAAAAAcLoEQQAAAAAwI\\u002fy0AAAAAAgGDGQAAAAAAAr8tAAAAAAIAhy0AAAAAAAPLBQAAAAACA78dAAAAAAIBUy0AAAAAAgO\u002fHQAAAAAAAoMtAAAAAAIB2yUAAAAAAgCHLQAAAAACAYMZAAAAAAIDwwUAAAAAAgFTLQAAAAAAALbdAAAAAAICJy0AAAAAAgHbJQAAAAAAArspAAAAAAACvy0AAAAAAgInLQAAAAAAALbdAAAAAAEDJ\u002fUAAAAAAcLH9QAAAAABwyfZAAAAAALB\u002f+kAAAAAA4N\u002f9QAAAAADgJflAAAAAANB2\u002fEAAAAAA0D39QAAAAADQ3\u002f1AAAAAANB\u002f+kAAAAAAcPX8QAAAAAAg+\u002ftAAAAAALB2\u002fEAAAAAA4D39QAAAAACAsf1AAAAAADD7+0AAAAAAcGP7QAAAAADQlv1AAAAAALBx\...\\u002f2EAAAAAAwCTcQAAAAABA0dRAAAAAAABu0EAAAAAAAATbQAAAAACAI9pAAAAAAICP20AAAAAAwJncQAAAAAAAM8NAAAAAAEDX20AAAAAAgDvbQAAAAAAAmbdAAAAAAIBNwEAAAAAAAKq6QAAAAAAAGblAAAAAAADVvkAAAAAAAOi\u002fQAAAAAAAzrxAAAAAAAB+wEAAAAAAAMiiQAAAAAAA5qdAAAAAAADeo0AAAAAAAGimQAAAAAAAiqRAAAAAAADApUAAAAAAAAynQAAAAAAADqBAAAAAAACeoUAAAAAAACClQAAAAAAAfKdA ...
# Model: Ridge
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="475d2000-af97-4ffa-a5bf-960d0a736011" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("475d2000-af97-4ffa-a5bf-960d0a736011")) {                    Plotly.newPlot(                        "475d2000-af97-4ffa-a5bf-960d0a736011",                        [{"mode":"markers","name":"Predictions","x":{"dtype":"f8","bdata":"\u002fyQAAAAABwsPBAAAAAAADN8kAAAAAAoObyQAAAAADA+vJAAAAAALA08kAAAAAAAAnZQAAAAADA1dpAAAAAAABm2kAAAAAAQOPaQAAAAADA\...\...\...\...\...\u002fQQAAABD1aIFBAAAAAAStgEEAAACYu9uBQQAAAGAkZ4BBAAAAEPVogUEAAACgLDCAQQAAAAAErYBBAAAAIJoTfkEAAAAABK2AQQAAAPgjZ4BBAAAA0Ar1gEEAAACgLDCAQQAAAJi724FBAAAAAGjmKEEAAAAAzLopQQAAAADgqSdBAAAAAMjcDEEAAAAARgEuQQAAAAC8pSBBAAAAAD4\...\u002fbkpBAAAAgLIPU0EAAABA9VdTQQAAAIBKikVBAAAAQB7AU0EAAACAxFhLQQAAAADAduZAAAAAAGDC40AAAAAwvRx2QQAAAID4\\u002ftAAAAAAMDvBUEAAAAAiHAAQQAAAADQoP5AAAAAANhaBEEAAAAA2GsFQQAAAABgWQJBAAAAAIhHBkEAAAAAADwFQQAAAACETRJBAAAAAPCIB0EAAAAAMPgOQQAAAABISQlBAAAAALj7DEEAAAAAJHIQQQAAAADgR\\...\u002flbQQAAAIBlIl5BAAAAgJLpWEEAAAAgtYZgQQAAAABC911BAAAAgAc7YEEAAACAj5lcQQAAAICPmVxBAAAAQL8LYUEAAADAHeBfQQAAAEC\\u002fmJBAAAAgHnsaEEAAAAAhuNlQQAAAIAg92pBAAAAgAbIZ0EAAAAAYT1qQQAAAAAt\\...\u002f\...\u002fCZBAAAAAHImI0EAAAAAuJ8pQQAAAAAE0ChBAAAAANQBNUEAAAAAI+IzQQAAAAApiTdBAAAAAGBeOEEAAAAAZDs2QQAAAAA07TFBAAAAAEgRN0EAAAAARcc1QQAAAABE\u002fjdBAAAAAG+SNkEAAACAublzQQAAAKAUhnNBAAAAUEcNcEEAAABAtBxjQQAAAADbqHFBAAAA8BBfc0EAAAAgH8JyQQAAAEBWS1lBAAAAYD8uc0EAAAAwH\...\...\u002fEAAAADg\u002fVd0QQAAAHDnIX1BAAAAcOchfUEAAACYgeaAQQAAABBFP4NBAAAACEU\\...\u002fg0EAAADg\u002fVd0QQAAALAlXHRBAAAAkGcbeUEAAABw5yF9QQAAAMDNpoNBAAAAIEh0hEEAAABAfKJSQQAAAGC9O2pBAAAAsDBcdEEAAADIgeaAQQAAAHid7YNBAAAAEEU\...\...\u002fNUaQQAAAADcdSZBAAAAAJ+VMEEAAAAAn5UwQQAAAABWYzFBAAAAAMx1JkEAAAAA\u002fNUaQQAAAADSlzBBAAAAAMx1JkEAAAAAwe4xQQAAAAAKBi9BAAAAANIIL0EAAAAA\u002fNUaQQA ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="3d20a01e-f62f-4a43-9eff-e6c26ec71eeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3d20a01e-f62f-4a43-9eff-e6c26ec71eeb")) {                    Plotly.newPlot(                        "3d20a01e-f62f-4a43-9eff-e6c26ec71eeb",                        [{"mode":"markers","name":"Predictions","x":{"dtype":"f8","bdata":"AAAAAMBh6UAAAAAAiJoDQQAAAACAmgNBAAAAAEDgBUEAAAAAQL4FQQAAAABgHwVBAAAAALgYA0EAAAAA8BoAQQAAAAA44AVBAAAAAJCZAUEAAAAAgF0FQQAAAAD4ggJBAAAAADjYBEEAAAAAiHgEQQAAAADwggJBAAAAAAiTBUEAAAAAABsAQQAAAAAw4AVBAAAAAIB4BEEAAAAAuJkBQQAAAADg\...\u002f0AAAAAAwHLwQAAAAAAge\u002fhAAAAAABDpBUEAAAAAkHH0QAAAAABIvgZBAAAAAPBy8EAAAAAA4Nb\u002fQAAAAACge\u002fhAAAAAAKDX\u002f0AAAAAAQHL0QAAAAACQcvRAAAAAAICqAkEAAAAAYJgBQQAAAADI6QVBAAAAAOBc60AAAAAA0Lv7QAAAAACwu\u002ftAAAAAAKiYAUEAAAAAUJgBQQAAAABIqgJBAAAAAEBy8EAAAAAAGDwFQQAAAACIqgJBAAAAAPA7BUEAAAAAoJgBQQAAAABgqgJBAAAAAOBZ60AAAAAAWJgBQQAAAABQ1v9AAAAAAJCcA0EAAAAAwLz7QAAAAADwu\u002ftAAAAAALiFB0EAAAAAsLz7QAAAAAAo6QVBAAAAAGBy8EAAAAAAIOkFQQAAAABgcfRAAAAAAJicA0EAAAAAuJwDQQAAAADAevhAAAAAALCFB0EAAAAA8JwDQQAAAACQcfRAAAAAAEiqAkEAAAAA4HLwQAAAAACgWutAAAAAAMCFBEEAAAAAoHH0QAAAAAAA6QVBAAAAAAB7+EAAAAAAUNf\u002fQAAAAABQqgJBAAAAABjpBUEAAAAA0IUHQQAAAADA1v9AAAAAALBx9EAAAAAA8Lv7QAAAAAA4vgZBAAAAANBy8EAAAAAA+DsFQQAAAABYmAFBAAAAAECqAkEAAAAAoNb\u002fQAAAAADAhQdBAAAAAAjpBUEAAAAA+DsFQQAAAADQe\...\...\u002fJZAAAAAAIBD4kAAAAAAYJ\u002fiQAAAAABgr+JAAAAAAEBD4kAAAAAAAI3iQAAAAABgQ+JAAAAAAADgsUAAAAAAACuxQAAAAAAAK7FAAAAAAADMsUAAAAAAAPyxQAAAAAAAnbFAAAAAAADosUAAAAAAAJ2xQAAAAAAA87FAAAAAAAABskAAAAAAwG3SQAAAAAAAatJAAAAAAMBO0kAAAAAAgGzSQAAAAADATtJAAAAAAABt0kAAAAAAAGrSQAAAAABAbdJAAAAAACD\u002f6EAAAAAAwMHlQAAAAADgpudAAAAAACAS60AAAAAAABLrQAAAAADgOepAAAAAAIDB5UAAAAAAQP\u002foQAAAAAAgp+dAAAAAAKA56kAAAAAAIMLlQAAAAABgPONAAAAAACDN40AAAAAAgMbmQAAAAAAAO+VAAAAAAIA\u002f50AAAAAAQJTmQAAAAAAgT+ZAAAAAAKBP50AAAAAA4DrlQAAAAADAEudAAAAAAIDG5kAAAAAAwPzlQAAAAABg\u002fuZAAAAAAIAj50AAAAAAYP7mQAAAAAAAzeNAAAAAAKDM40AAAAAAYOjmQAAAAACg\...\u002fXQAAAAABAv9dAAAAAAADEpUAAAAAAABiiQAAAAABQXQhBAAAAAHAj\u002fEAAAAAAaKcGQQAAAADwUQdBAAAAAEBvCUEAAAAAyPAFQQAAAADoXAhBAAAAABAi\u002fEAAAAAAyPAFQQAAAADAIvxAAAAAAOhRB0EAAAAAACP8QAAAAACApwZBAAAAALDwBUEAAAAAIF0IQQAAAADA8AVBAAAAAOAh\u002fEAAAAAAGFIHQQAAAACYbwlBAAAAAPBcCEEAAAAAeLoEQQAAAAAQ5fFAAAAAANhvAkEAAAAAWF0IQQAAAACIbwlBAAAAAEhdCEEAAAAAcLoEQQAAAAAwI\\u002fy0AAAAAAgGDGQAAAAAAAr8tAAAAAAIAhy0AAAAAAAPLBQAAAAACA78dAAAAAAIBUy0AAAAAAgO\u002fHQAAAAAAAoMtAAAAAAIB2yUAAAAAAgCHLQAAAAACAYMZAAAAAAIDwwUAAAAAAgFTLQAAAAAAALbdAAAAAAICJy0AAAAAAgHbJQAAAAAAArspAAAAAAACvy0AAAAAAgInLQAAAAAAALbdAAAAAAEDJ\u002fUAAAAAAcLH9QAAAAABwyfZAAAAAALB\u002f+kAAAAAA4N\u002f9QAAAAADgJflAAAAAANB2\u002fEAAAAAA0D39QAAAAADQ3\u002f1AAAAAANB\u002f+kAAAAAAcPX8QAAAAAAg+\u002ftAAAAAALB2\u002fEAAAAAA4D39QAAAAACAsf1AAAAAADD7+0AAAAAAcGP7QAAAAADQlv1AAAAAALBx\...\\u002f2EAAAAAAwCTcQAAAAABA0dRAAAAAAABu0EAAAAAAAATbQAAAAACAI9pAAAAAAICP20AAAAAAwJncQAAAAAAAM8NAAAAAAEDX20AAAAAAgDvbQAAAAAAAmbdAAAAAAIBNwEAAAAAAAKq6QAAAAAAAGblAAAAAAADVvkAAAAAAAOi\u002fQAAAAAAAzrxAAAAAAAB+wEAAAAAAAMiiQAAAAAAA5qdAAAAAAADeo0AAAAAAAGimQAAAAAAAiqRAAAAAAADApUAAAAAAAAynQAAAAAAADqBAAAAAAACeoUAAAAAAACClQAAAAAAAfKdA ...
# Model: Lasso
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="58618d6a-4214-4253-b78b-786f1c619d03" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("58618d6a-4214-4253-b78b-786f1c619d03")) {                    Plotly.newPlot(                        "58618d6a-4214-4253-b78b-786f1c619d03",                        [{"mode":"markers","name":"Predictions","x":{"dtype":"f8","bdata":"\u002fyQAAAAABwsPBAAAAAAADN8kAAAAAAoObyQAAAAADA+vJAAAAAALA08kAAAAAAAAnZQAAAAADA1dpAAAAAAABm2kAAAAAAQOPaQAAAAADA\...\...\...\...\...\u002fQQAAABD1aIFBAAAAAAStgEEAAACYu9uBQQAAAGAkZ4BBAAAAEPVogUEAAACgLDCAQQAAAAAErYBBAAAAIJoTfkEAAAAABK2AQQAAAPgjZ4BBAAAA0Ar1gEEAAACgLDCAQQAAAJi724FBAAAAAGjmKEEAAAAAzLopQQAAAADgqSdBAAAAAMjcDEEAAAAARgEuQQAAAAC8pSBBAAAAAD4\...\u002fbkpBAAAAgLIPU0EAAABA9VdTQQAAAIBKikVBAAAAQB7AU0EAAACAxFhLQQAAAADAduZAAAAAAGDC40AAAAAwvRx2QQAAAID4\\u002ftAAAAAAMDvBUEAAAAAiHAAQQAAAADQoP5AAAAAANhaBEEAAAAA2GsFQQAAAABgWQJBAAAAAIhHBkEAAAAAADwFQQAAAACETRJBAAAAAPCIB0EAAAAAMPgOQQAAAABISQlBAAAAALj7DEEAAAAAJHIQQQAAAADgR\\...\u002flbQQAAAIBlIl5BAAAAgJLpWEEAAAAgtYZgQQAAAABC911BAAAAgAc7YEEAAACAj5lcQQAAAICPmVxBAAAAQL8LYUEAAADAHeBfQQAAAEC\\u002fmJBAAAAgHnsaEEAAAAAhuNlQQAAAIAg92pBAAAAgAbIZ0EAAAAAYT1qQQAAAAAt\\...\u002f\...\u002fCZBAAAAAHImI0EAAAAAuJ8pQQAAAAAE0ChBAAAAANQBNUEAAAAAI+IzQQAAAAApiTdBAAAAAGBeOEEAAAAAZDs2QQAAAAA07TFBAAAAAEgRN0EAAAAARcc1QQAAAABE\u002fjdBAAAAAG+SNkEAAACAublzQQAAAKAUhnNBAAAAUEcNcEEAAABAtBxjQQAAAADbqHFBAAAA8BBfc0EAAAAgH8JyQQAAAEBWS1lBAAAAYD8uc0EAAAAwH\...\...\u002fEAAAADg\u002fVd0QQAAAHDnIX1BAAAAcOchfUEAAACYgeaAQQAAABBFP4NBAAAACEU\\...\u002fg0EAAADg\u002fVd0QQAAALAlXHRBAAAAkGcbeUEAAABw5yF9QQAAAMDNpoNBAAAAIEh0hEEAAABAfKJSQQAAAGC9O2pBAAAAsDBcdEEAAADIgeaAQQAAAHid7YNBAAAAEEU\...\...\u002fNUaQQAAAADcdSZBAAAAAJ+VMEEAAAAAn5UwQQAAAABWYzFBAAAAAMx1JkEAAAAA\u002fNUaQQAAAADSlzBBAAAAAMx1JkEAAAAAwe4xQQAAAAAKBi9BAAAAANIIL0EAAAAA\u002fNUaQQA ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="81b1ea03-8d8d-48d8-8d39-5db361baa243" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("81b1ea03-8d8d-48d8-8d39-5db361baa243")) {                    Plotly.newPlot(                        "81b1ea03-8d8d-48d8-8d39-5db361baa243",                        [{"mode":"markers","name":"Predictions","x":{"dtype":"f8","bdata":"AAAAAMBh6UAAAAAAiJoDQQAAAACAmgNBAAAAAEDgBUEAAAAAQL4FQQAAAABgHwVBAAAAALgYA0EAAAAA8BoAQQAAAAA44AVBAAAAAJCZAUEAAAAAgF0FQQAAAAD4ggJBAAAAADjYBEEAAAAAiHgEQQAAAADwggJBAAAAAAiTBUEAAAAAABsAQQAAAAAw4AVBAAAAAIB4BEEAAAAAuJkBQQAAAADg\...\u002f0AAAAAAwHLwQAAAAAAge\u002fhAAAAAABDpBUEAAAAAkHH0QAAAAABIvgZBAAAAAPBy8EAAAAAA4Nb\u002fQAAAAACge\u002fhAAAAAAKDX\u002f0AAAAAAQHL0QAAAAACQcvRAAAAAAICqAkEAAAAAYJgBQQAAAADI6QVBAAAAAOBc60AAAAAA0Lv7QAAAAACwu\u002ftAAAAAAKiYAUEAAAAAUJgBQQAAAABIqgJBAAAAAEBy8EAAAAAAGDwFQQAAAACIqgJBAAAAAPA7BUEAAAAAoJgBQQAAAABgqgJBAAAAAOBZ60AAAAAAWJgBQQAAAABQ1v9AAAAAAJCcA0EAAAAAwLz7QAAAAADwu\u002ftAAAAAALiFB0EAAAAAsLz7QAAAAAAo6QVBAAAAAGBy8EAAAAAAIOkFQQAAAABgcfRAAAAAAJicA0EAAAAAuJwDQQAAAADAevhAAAAAALCFB0EAAAAA8JwDQQAAAACQcfRAAAAAAEiqAkEAAAAA4HLwQAAAAACgWutAAAAAAMCFBEEAAAAAoHH0QAAAAAAA6QVBAAAAAAB7+EAAAAAAUNf\u002fQAAAAABQqgJBAAAAABjpBUEAAAAA0IUHQQAAAADA1v9AAAAAALBx9EAAAAAA8Lv7QAAAAAA4vgZBAAAAANBy8EAAAAAA+DsFQQAAAABYmAFBAAAAAECqAkEAAAAAoNb\u002fQAAAAADAhQdBAAAAAAjpBUEAAAAA+DsFQQAAAADQe\...\...\u002fJZAAAAAAIBD4kAAAAAAYJ\u002fiQAAAAABgr+JAAAAAAEBD4kAAAAAAAI3iQAAAAABgQ+JAAAAAAADgsUAAAAAAACuxQAAAAAAAK7FAAAAAAADMsUAAAAAAAPyxQAAAAAAAnbFAAAAAAADosUAAAAAAAJ2xQAAAAAAA87FAAAAAAAABskAAAAAAwG3SQAAAAAAAatJAAAAAAMBO0kAAAAAAgGzSQAAAAADATtJAAAAAAABt0kAAAAAAAGrSQAAAAABAbdJAAAAAACD\u002f6EAAAAAAwMHlQAAAAADgpudAAAAAACAS60AAAAAAABLrQAAAAADgOepAAAAAAIDB5UAAAAAAQP\u002foQAAAAAAgp+dAAAAAAKA56kAAAAAAIMLlQAAAAABgPONAAAAAACDN40AAAAAAgMbmQAAAAAAAO+VAAAAAAIA\u002f50AAAAAAQJTmQAAAAAAgT+ZAAAAAAKBP50AAAAAA4DrlQAAAAADAEudAAAAAAIDG5kAAAAAAwPzlQAAAAABg\u002fuZAAAAAAIAj50AAAAAAYP7mQAAAAAAAzeNAAAAAAKDM40AAAAAAYOjmQAAAAACg\...\u002fXQAAAAABAv9dAAAAAAADEpUAAAAAAABiiQAAAAABQXQhBAAAAAHAj\u002fEAAAAAAaKcGQQAAAADwUQdBAAAAAEBvCUEAAAAAyPAFQQAAAADoXAhBAAAAABAi\u002fEAAAAAAyPAFQQAAAADAIvxAAAAAAOhRB0EAAAAAACP8QAAAAACApwZBAAAAALDwBUEAAAAAIF0IQQAAAADA8AVBAAAAAOAh\u002fEAAAAAAGFIHQQAAAACYbwlBAAAAAPBcCEEAAAAAeLoEQQAAAAAQ5fFAAAAAANhvAkEAAAAAWF0IQQAAAACIbwlBAAAAAEhdCEEAAAAAcLoEQQAAAAAwI\\u002fy0AAAAAAgGDGQAAAAAAAr8tAAAAAAIAhy0AAAAAAAPLBQAAAAACA78dAAAAAAIBUy0AAAAAAgO\u002fHQAAAAAAAoMtAAAAAAIB2yUAAAAAAgCHLQAAAAACAYMZAAAAAAIDwwUAAAAAAgFTLQAAAAAAALbdAAAAAAICJy0AAAAAAgHbJQAAAAAAArspAAAAAAACvy0AAAAAAgInLQAAAAAAALbdAAAAAAEDJ\u002fUAAAAAAcLH9QAAAAABwyfZAAAAAALB\u002f+kAAAAAA4N\u002f9QAAAAADgJflAAAAAANB2\u002fEAAAAAA0D39QAAAAADQ3\u002f1AAAAAANB\u002f+kAAAAAAcPX8QAAAAAAg+\u002ftAAAAAALB2\u002fEAAAAAA4D39QAAAAACAsf1AAAAAADD7+0AAAAAAcGP7QAAAAADQlv1AAAAAALBx\...\\u002f2EAAAAAAwCTcQAAAAABA0dRAAAAAAABu0EAAAAAAAATbQAAAAACAI9pAAAAAAICP20AAAAAAwJncQAAAAAAAM8NAAAAAAEDX20AAAAAAgDvbQAAAAAAAmbdAAAAAAIBNwEAAAAAAAKq6QAAAAAAAGblAAAAAAADVvkAAAAAAAOi\u002fQAAAAAAAzrxAAAAAAAB+wEAAAAAAAMiiQAAAAAAA5qdAAAAAAADeo0AAAAAAAGimQAAAAAAAiqRAAAAAAADApUAAAAAAAAynQAAAAAAADqBAAAAAAACeoUAAAAAAACClQAAAAAAAfKdA ...
# Model: Decision_Tree
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="cba417ff-b831-4dc0-9ac6-d173200faea1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cba417ff-b831-4dc0-9ac6-d173200faea1")) {                    Plotly.newPlot(                        "cba417ff-b831-4dc0-9ac6-d173200faea1",                        [{"mode":"markers","name":"Predictions","x":{"dtype":"f8","bdata":"\u002fyQAAAAABwsPBAAAAAAADN8kAAAAAAoObyQAAAAADA+vJAAAAAALA08kAAAAAAAAnZQAAAAADA1dpAAAAAAABm2kAAAAAAQOPaQAAAAADA\...\...\...\...\...\u002fQQAAABD1aIFBAAAAAAStgEEAAACYu9uBQQAAAGAkZ4BBAAAAEPVogUEAAACgLDCAQQAAAAAErYBBAAAAIJoTfkEAAAAABK2AQQAAAPgjZ4BBAAAA0Ar1gEEAAACgLDCAQQAAAJi724FBAAAAAGjmKEEAAAAAzLopQQAAAADgqSdBAAAAAMjcDEEAAAAARgEuQQAAAAC8pSBBAAAAAD4\...\u002fbkpBAAAAgLIPU0EAAABA9VdTQQAAAIBKikVBAAAAQB7AU0EAAACAxFhLQQAAAADAduZAAAAAAGDC40AAAAAwvRx2QQAAAID4\\u002ftAAAAAAMDvBUEAAAAAiHAAQQAAAADQoP5AAAAAANhaBEEAAAAA2GsFQQAAAABgWQJBAAAAAIhHBkEAAAAAADwFQQAAAACETRJBAAAAAPCIB0EAAAAAMPgOQQAAAABISQlBAAAAALj7DEEAAAAAJHIQQQAAAADgR\\...\u002flbQQAAAIBlIl5BAAAAgJLpWEEAAAAgtYZgQQAAAABC911BAAAAgAc7YEEAAACAj5lcQQAAAICPmVxBAAAAQL8LYUEAAADAHeBfQQAAAEC\\u002fmJBAAAAgHnsaEEAAAAAhuNlQQAAAIAg92pBAAAAgAbIZ0EAAAAAYT1qQQAAAAAt\\...\u002f\...\u002fCZBAAAAAHImI0EAAAAAuJ8pQQAAAAAE0ChBAAAAANQBNUEAAAAAI+IzQQAAAAApiTdBAAAAAGBeOEEAAAAAZDs2QQAAAAA07TFBAAAAAEgRN0EAAAAARcc1QQAAAABE\u002fjdBAAAAAG+SNkEAAACAublzQQAAAKAUhnNBAAAAUEcNcEEAAABAtBxjQQAAAADbqHFBAAAA8BBfc0EAAAAgH8JyQQAAAEBWS1lBAAAAYD8uc0EAAAAwH\...\...\u002fEAAAADg\u002fVd0QQAAAHDnIX1BAAAAcOchfUEAAACYgeaAQQAAABBFP4NBAAAACEU\\...\u002fg0EAAADg\u002fVd0QQAAALAlXHRBAAAAkGcbeUEAAABw5yF9QQAAAMDNpoNBAAAAIEh0hEEAAABAfKJSQQAAAGC9O2pBAAAAsDBcdEEAAADIgeaAQQAAAHid7YNBAAAAEEU\...\...\u002fNUaQQAAAADcdSZBAAAAAJ+VMEEAAAAAn5UwQQAAAABWYzFBAAAAAMx1JkEAAAAA\u002fNUaQQAAAADSlzBBAAAAAMx1JkEAAAAAwe4xQQAAAAAKBi9BAAAAANIIL0EAAAAA\u002fNUaQQA ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="875d8950-6537-4fa9-a890-8ef1bc10b7ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("875d8950-6537-4fa9-a890-8ef1bc10b7ad")) {                    Plotly.newPlot(                        "875d8950-6537-4fa9-a890-8ef1bc10b7ad",                        [{"mode":"markers","name":"Predictions","x":{"dtype":"f8","bdata":"AAAAAMBh6UAAAAAAiJoDQQAAAACAmgNBAAAAAEDgBUEAAAAAQL4FQQAAAABgHwVBAAAAALgYA0EAAAAA8BoAQQAAAAA44AVBAAAAAJCZAUEAAAAAgF0FQQAAAAD4ggJBAAAAADjYBEEAAAAAiHgEQQAAAADwggJBAAAAAAiTBUEAAAAAABsAQQAAAAAw4AVBAAAAAIB4BEEAAAAAuJkBQQAAAADg\...\u002f0AAAAAAwHLwQAAAAAAge\u002fhAAAAAABDpBUEAAAAAkHH0QAAAAABIvgZBAAAAAPBy8EAAAAAA4Nb\u002fQAAAAACge\u002fhAAAAAAKDX\u002f0AAAAAAQHL0QAAAAACQcvRAAAAAAICqAkEAAAAAYJgBQQAAAADI6QVBAAAAAOBc60AAAAAA0Lv7QAAAAACwu\u002ftAAAAAAKiYAUEAAAAAUJgBQQAAAABIqgJBAAAAAEBy8EAAAAAAGDwFQQAAAACIqgJBAAAAAPA7BUEAAAAAoJgBQQAAAABgqgJBAAAAAOBZ60AAAAAAWJgBQQAAAABQ1v9AAAAAAJCcA0EAAAAAwLz7QAAAAADwu\u002ftAAAAAALiFB0EAAAAAsLz7QAAAAAAo6QVBAAAAAGBy8EAAAAAAIOkFQQAAAABgcfRAAAAAAJicA0EAAAAAuJwDQQAAAADAevhAAAAAALCFB0EAAAAA8JwDQQAAAACQcfRAAAAAAEiqAkEAAAAA4HLwQAAAAACgWutAAAAAAMCFBEEAAAAAoHH0QAAAAAAA6QVBAAAAAAB7+EAAAAAAUNf\u002fQAAAAABQqgJBAAAAABjpBUEAAAAA0IUHQQAAAADA1v9AAAAAALBx9EAAAAAA8Lv7QAAAAAA4vgZBAAAAANBy8EAAAAAA+DsFQQAAAABYmAFBAAAAAECqAkEAAAAAoNb\u002fQAAAAADAhQdBAAAAAAjpBUEAAAAA+DsFQQAAAADQe\...\...\u002fJZAAAAAAIBD4kAAAAAAYJ\u002fiQAAAAABgr+JAAAAAAEBD4kAAAAAAAI3iQAAAAABgQ+JAAAAAAADgsUAAAAAAACuxQAAAAAAAK7FAAAAAAADMsUAAAAAAAPyxQAAAAAAAnbFAAAAAAADosUAAAAAAAJ2xQAAAAAAA87FAAAAAAAABskAAAAAAwG3SQAAAAAAAatJAAAAAAMBO0kAAAAAAgGzSQAAAAADATtJAAAAAAABt0kAAAAAAAGrSQAAAAABAbdJAAAAAACD\u002f6EAAAAAAwMHlQAAAAADgpudAAAAAACAS60AAAAAAABLrQAAAAADgOepAAAAAAIDB5UAAAAAAQP\u002foQAAAAAAgp+dAAAAAAKA56kAAAAAAIMLlQAAAAABgPONAAAAAACDN40AAAAAAgMbmQAAAAAAAO+VAAAAAAIA\u002f50AAAAAAQJTmQAAAAAAgT+ZAAAAAAKBP50AAAAAA4DrlQAAAAADAEudAAAAAAIDG5kAAAAAAwPzlQAAAAABg\u002fuZAAAAAAIAj50AAAAAAYP7mQAAAAAAAzeNAAAAAAKDM40AAAAAAYOjmQAAAAACg\...\u002fXQAAAAABAv9dAAAAAAADEpUAAAAAAABiiQAAAAABQXQhBAAAAAHAj\u002fEAAAAAAaKcGQQAAAADwUQdBAAAAAEBvCUEAAAAAyPAFQQAAAADoXAhBAAAAABAi\u002fEAAAAAAyPAFQQAAAADAIvxAAAAAAOhRB0EAAAAAACP8QAAAAACApwZBAAAAALDwBUEAAAAAIF0IQQAAAADA8AVBAAAAAOAh\u002fEAAAAAAGFIHQQAAAACYbwlBAAAAAPBcCEEAAAAAeLoEQQAAAAAQ5fFAAAAAANhvAkEAAAAAWF0IQQAAAACIbwlBAAAAAEhdCEEAAAAAcLoEQQAAAAAwI\\u002fy0AAAAAAgGDGQAAAAAAAr8tAAAAAAIAhy0AAAAAAAPLBQAAAAACA78dAAAAAAIBUy0AAAAAAgO\u002fHQAAAAAAAoMtAAAAAAIB2yUAAAAAAgCHLQAAAAACAYMZAAAAAAIDwwUAAAAAAgFTLQAAAAAAALbdAAAAAAICJy0AAAAAAgHbJQAAAAAAArspAAAAAAACvy0AAAAAAgInLQAAAAAAALbdAAAAAAEDJ\u002fUAAAAAAcLH9QAAAAABwyfZAAAAAALB\u002f+kAAAAAA4N\u002f9QAAAAADgJflAAAAAANB2\u002fEAAAAAA0D39QAAAAADQ3\u002f1AAAAAANB\u002f+kAAAAAAcPX8QAAAAAAg+\u002ftAAAAAALB2\u002fEAAAAAA4D39QAAAAACAsf1AAAAAADD7+0AAAAAAcGP7QAAAAADQlv1AAAAAALBx\...\\u002f2EAAAAAAwCTcQAAAAABA0dRAAAAAAABu0EAAAAAAAATbQAAAAACAI9pAAAAAAICP20AAAAAAwJncQAAAAAAAM8NAAAAAAEDX20AAAAAAgDvbQAAAAAAAmbdAAAAAAIBNwEAAAAAAAKq6QAAAAAAAGblAAAAAAADVvkAAAAAAAOi\u002fQAAAAAAAzrxAAAAAAAB+wEAAAAAAAMiiQAAAAAAA5qdAAAAAAADeo0AAAAAAAGimQAAAAAAAiqRAAAAAAADApUAAAAAAAAynQAAAAAAADqBAAAAAAACeoUAAAAAAACClQAAAAAAAfKdA ...
# Model: Random_Forest
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="2374aa49-c7da-47ad-af84-e0a84ff0f454" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2374aa49-c7da-47ad-af84-e0a84ff0f454")) {                    Plotly.newPlot(                        "2374aa49-c7da-47ad-af84-e0a84ff0f454",                        [{"mode":"markers","name":"Predictions","x":{"dtype":"f8","bdata":"\u002fyQAAAAABwsPBAAAAAAADN8kAAAAAAoObyQAAAAADA+vJAAAAAALA08kAAAAAAAAnZQAAAAADA1dpAAAAAAABm2kAAAAAAQOPaQAAAAADA\...\...\...\...\...\u002fQQAAABD1aIFBAAAAAAStgEEAAACYu9uBQQAAAGAkZ4BBAAAAEPVogUEAAACgLDCAQQAAAAAErYBBAAAAIJoTfkEAAAAABK2AQQAAAPgjZ4BBAAAA0Ar1gEEAAACgLDCAQQAAAJi724FBAAAAAGjmKEEAAAAAzLopQQAAAADgqSdBAAAAAMjcDEEAAAAARgEuQQAAAAC8pSBBAAAAAD4\...\u002fbkpBAAAAgLIPU0EAAABA9VdTQQAAAIBKikVBAAAAQB7AU0EAAACAxFhLQQAAAADAduZAAAAAAGDC40AAAAAwvRx2QQAAAID4\\u002ftAAAAAAMDvBUEAAAAAiHAAQQAAAADQoP5AAAAAANhaBEEAAAAA2GsFQQAAAABgWQJBAAAAAIhHBkEAAAAAADwFQQAAAACETRJBAAAAAPCIB0EAAAAAMPgOQQAAAABISQlBAAAAALj7DEEAAAAAJHIQQQAAAADgR\\...\u002flbQQAAAIBlIl5BAAAAgJLpWEEAAAAgtYZgQQAAAABC911BAAAAgAc7YEEAAACAj5lcQQAAAICPmVxBAAAAQL8LYUEAAADAHeBfQQAAAEC\\u002fmJBAAAAgHnsaEEAAAAAhuNlQQAAAIAg92pBAAAAgAbIZ0EAAAAAYT1qQQAAAAAt\\...\u002f\...\u002fCZBAAAAAHImI0EAAAAAuJ8pQQAAAAAE0ChBAAAAANQBNUEAAAAAI+IzQQAAAAApiTdBAAAAAGBeOEEAAAAAZDs2QQAAAAA07TFBAAAAAEgRN0EAAAAARcc1QQAAAABE\u002fjdBAAAAAG+SNkEAAACAublzQQAAAKAUhnNBAAAAUEcNcEEAAABAtBxjQQAAAADbqHFBAAAA8BBfc0EAAAAgH8JyQQAAAEBWS1lBAAAAYD8uc0EAAAAwH\...\...\u002fEAAAADg\u002fVd0QQAAAHDnIX1BAAAAcOchfUEAAACYgeaAQQAAABBFP4NBAAAACEU\\...\u002fg0EAAADg\u002fVd0QQAAALAlXHRBAAAAkGcbeUEAAABw5yF9QQAAAMDNpoNBAAAAIEh0hEEAAABAfKJSQQAAAGC9O2pBAAAAsDBcdEEAAADIgeaAQQAAAHid7YNBAAAAEEU\...\...\u002fNUaQQAAAADcdSZBAAAAAJ+VMEEAAAAAn5UwQQAAAABWYzFBAAAAAMx1JkEAAAAA\u002fNUaQQAAAADSlzBBAAAAAMx1JkEAAAAAwe4xQQAAAAAKBi9BAAAAANIIL0EAAAAA\u002fNUaQQA ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="4e11fe3a-a53f-4b49-8dbd-66484c2b9eb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4e11fe3a-a53f-4b49-8dbd-66484c2b9eb7")) {                    Plotly.newPlot(                        "4e11fe3a-a53f-4b49-8dbd-66484c2b9eb7",                        [{"mode":"markers","name":"Predictions","x":{"dtype":"f8","bdata":"AAAAAMBh6UAAAAAAiJoDQQAAAACAmgNBAAAAAEDgBUEAAAAAQL4FQQAAAABgHwVBAAAAALgYA0EAAAAA8BoAQQAAAAA44AVBAAAAAJCZAUEAAAAAgF0FQQAAAAD4ggJBAAAAADjYBEEAAAAAiHgEQQAAAADwggJBAAAAAAiTBUEAAAAAABsAQQAAAAAw4AVBAAAAAIB4BEEAAAAAuJkBQQAAAADg\...\u002f0AAAAAAwHLwQAAAAAAge\u002fhAAAAAABDpBUEAAAAAkHH0QAAAAABIvgZBAAAAAPBy8EAAAAAA4Nb\u002fQAAAAACge\u002fhAAAAAAKDX\u002f0AAAAAAQHL0QAAAAACQcvRAAAAAAICqAkEAAAAAYJgBQQAAAADI6QVBAAAAAOBc60AAAAAA0Lv7QAAAAACwu\u002ftAAAAAAKiYAUEAAAAAUJgBQQAAAABIqgJBAAAAAEBy8EAAAAAAGDwFQQAAAACIqgJBAAAAAPA7BUEAAAAAoJgBQQAAAABgqgJBAAAAAOBZ60AAAAAAWJgBQQAAAABQ1v9AAAAAAJCcA0EAAAAAwLz7QAAAAADwu\u002ftAAAAAALiFB0EAAAAAsLz7QAAAAAAo6QVBAAAAAGBy8EAAAAAAIOkFQQAAAABgcfRAAAAAAJicA0EAAAAAuJwDQQAAAADAevhAAAAAALCFB0EAAAAA8JwDQQAAAACQcfRAAAAAAEiqAkEAAAAA4HLwQAAAAACgWutAAAAAAMCFBEEAAAAAoHH0QAAAAAAA6QVBAAAAAAB7+EAAAAAAUNf\u002fQAAAAABQqgJBAAAAABjpBUEAAAAA0IUHQQAAAADA1v9AAAAAALBx9EAAAAAA8Lv7QAAAAAA4vgZBAAAAANBy8EAAAAAA+DsFQQAAAABYmAFBAAAAAECqAkEAAAAAoNb\u002fQAAAAADAhQdBAAAAAAjpBUEAAAAA+DsFQQAAAADQe\...\...\u002fJZAAAAAAIBD4kAAAAAAYJ\u002fiQAAAAABgr+JAAAAAAEBD4kAAAAAAAI3iQAAAAABgQ+JAAAAAAADgsUAAAAAAACuxQAAAAAAAK7FAAAAAAADMsUAAAAAAAPyxQAAAAAAAnbFAAAAAAADosUAAAAAAAJ2xQAAAAAAA87FAAAAAAAABskAAAAAAwG3SQAAAAAAAatJAAAAAAMBO0kAAAAAAgGzSQAAAAADATtJAAAAAAABt0kAAAAAAAGrSQAAAAABAbdJAAAAAACD\u002f6EAAAAAAwMHlQAAAAADgpudAAAAAACAS60AAAAAAABLrQAAAAADgOepAAAAAAIDB5UAAAAAAQP\u002foQAAAAAAgp+dAAAAAAKA56kAAAAAAIMLlQAAAAABgPONAAAAAACDN40AAAAAAgMbmQAAAAAAAO+VAAAAAAIA\u002f50AAAAAAQJTmQAAAAAAgT+ZAAAAAAKBP50AAAAAA4DrlQAAAAADAEudAAAAAAIDG5kAAAAAAwPzlQAAAAABg\u002fuZAAAAAAIAj50AAAAAAYP7mQAAAAAAAzeNAAAAAAKDM40AAAAAAYOjmQAAAAACg\...\u002fXQAAAAABAv9dAAAAAAADEpUAAAAAAABiiQAAAAABQXQhBAAAAAHAj\u002fEAAAAAAaKcGQQAAAADwUQdBAAAAAEBvCUEAAAAAyPAFQQAAAADoXAhBAAAAABAi\u002fEAAAAAAyPAFQQAAAADAIvxAAAAAAOhRB0EAAAAAACP8QAAAAACApwZBAAAAALDwBUEAAAAAIF0IQQAAAADA8AVBAAAAAOAh\u002fEAAAAAAGFIHQQAAAACYbwlBAAAAAPBcCEEAAAAAeLoEQQAAAAAQ5fFAAAAAANhvAkEAAAAAWF0IQQAAAACIbwlBAAAAAEhdCEEAAAAAcLoEQQAAAAAwI\\u002fy0AAAAAAgGDGQAAAAAAAr8tAAAAAAIAhy0AAAAAAAPLBQAAAAACA78dAAAAAAIBUy0AAAAAAgO\u002fHQAAAAAAAoMtAAAAAAIB2yUAAAAAAgCHLQAAAAACAYMZAAAAAAIDwwUAAAAAAgFTLQAAAAAAALbdAAAAAAICJy0AAAAAAgHbJQAAAAAAArspAAAAAAACvy0AAAAAAgInLQAAAAAAALbdAAAAAAEDJ\u002fUAAAAAAcLH9QAAAAABwyfZAAAAAALB\u002f+kAAAAAA4N\u002f9QAAAAADgJflAAAAAANB2\u002fEAAAAAA0D39QAAAAADQ3\u002f1AAAAAANB\u002f+kAAAAAAcPX8QAAAAAAg+\u002ftAAAAAALB2\u002fEAAAAAA4D39QAAAAACAsf1AAAAAADD7+0AAAAAAcGP7QAAAAADQlv1AAAAAALBx\...\\u002f2EAAAAAAwCTcQAAAAABA0dRAAAAAAABu0EAAAAAAAATbQAAAAACAI9pAAAAAAICP20AAAAAAwJncQAAAAAAAM8NAAAAAAEDX20AAAAAAgDvbQAAAAAAAmbdAAAAAAIBNwEAAAAAAAKq6QAAAAAAAGblAAAAAAADVvkAAAAAAAOi\u002fQAAAAAAAzrxAAAAAAAB+wEAAAAAAAMiiQAAAAAAA5qdAAAAAAADeo0AAAAAAAGimQAAAAAAAiqRAAAAAAADApUAAAAAAAAynQAAAAAAADqBAAAAAAACeoUAAAAAAACClQAAAAAAAfKdA ...
# Model: XGBoost
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="3f620db7-d354-44f4-ad52-87f0a9827bf0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3f620db7-d354-44f4-ad52-87f0a9827bf0")) {                    Plotly.newPlot(                        "3f620db7-d354-44f4-ad52-87f0a9827bf0",                        [{"mode":"markers","name":"Predictions","x":{"dtype":"f8","bdata":"\u002fyQAAAAABwsPBAAAAAAADN8kAAAAAAoObyQAAAAADA+vJAAAAAALA08kAAAAAAAAnZQAAAAADA1dpAAAAAAABm2kAAAAAAQOPaQAAAAADA\...\...\...\...\...\u002fQQAAABD1aIFBAAAAAAStgEEAAACYu9uBQQAAAGAkZ4BBAAAAEPVogUEAAACgLDCAQQAAAAAErYBBAAAAIJoTfkEAAAAABK2AQQAAAPgjZ4BBAAAA0Ar1gEEAAACgLDCAQQAAAJi724FBAAAAAGjmKEEAAAAAzLopQQAAAADgqSdBAAAAAMjcDEEAAAAARgEuQQAAAAC8pSBBAAAAAD4\...\u002fbkpBAAAAgLIPU0EAAABA9VdTQQAAAIBKikVBAAAAQB7AU0EAAACAxFhLQQAAAADAduZAAAAAAGDC40AAAAAwvRx2QQAAAID4\\u002ftAAAAAAMDvBUEAAAAAiHAAQQAAAADQoP5AAAAAANhaBEEAAAAA2GsFQQAAAABgWQJBAAAAAIhHBkEAAAAAADwFQQAAAACETRJBAAAAAPCIB0EAAAAAMPgOQQAAAABISQlBAAAAALj7DEEAAAAAJHIQQQAAAADgR\\...\u002flbQQAAAIBlIl5BAAAAgJLpWEEAAAAgtYZgQQAAAABC911BAAAAgAc7YEEAAACAj5lcQQAAAICPmVxBAAAAQL8LYUEAAADAHeBfQQAAAEC\\u002fmJBAAAAgHnsaEEAAAAAhuNlQQAAAIAg92pBAAAAgAbIZ0EAAAAAYT1qQQAAAAAt\\...\u002f\...\u002fCZBAAAAAHImI0EAAAAAuJ8pQQAAAAAE0ChBAAAAANQBNUEAAAAAI+IzQQAAAAApiTdBAAAAAGBeOEEAAAAAZDs2QQAAAAA07TFBAAAAAEgRN0EAAAAARcc1QQAAAABE\u002fjdBAAAAAG+SNkEAAACAublzQQAAAKAUhnNBAAAAUEcNcEEAAABAtBxjQQAAAADbqHFBAAAA8BBfc0EAAAAgH8JyQQAAAEBWS1lBAAAAYD8uc0EAAAAwH\...\...\u002fEAAAADg\u002fVd0QQAAAHDnIX1BAAAAcOchfUEAAACYgeaAQQAAABBFP4NBAAAACEU\\...\u002fg0EAAADg\u002fVd0QQAAALAlXHRBAAAAkGcbeUEAAABw5yF9QQAAAMDNpoNBAAAAIEh0hEEAAABAfKJSQQAAAGC9O2pBAAAAsDBcdEEAAADIgeaAQQAAAHid7YNBAAAAEEU\...\...\u002fNUaQQAAAADcdSZBAAAAAJ+VMEEAAAAAn5UwQQAAAABWYzFBAAAAAMx1JkEAAAAA\u002fNUaQQAAAADSlzBBAAAAAMx1JkEAAAAAwe4xQQAAAAAKBi9BAAAAANIIL0EAAAAA\u002fNUaQQA ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="4fd09e98-ee81-4e2d-b386-bc69e9f1980a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4fd09e98-ee81-4e2d-b386-bc69e9f1980a")) {                    Plotly.newPlot(                        "4fd09e98-ee81-4e2d-b386-bc69e9f1980a",                        [{"mode":"markers","name":"Predictions","x":{"dtype":"f8","bdata":"AAAAAMBh6UAAAAAAiJoDQQAAAACAmgNBAAAAAEDgBUEAAAAAQL4FQQAAAABgHwVBAAAAALgYA0EAAAAA8BoAQQAAAAA44AVBAAAAAJCZAUEAAAAAgF0FQQAAAAD4ggJBAAAAADjYBEEAAAAAiHgEQQAAAADwggJBAAAAAAiTBUEAAAAAABsAQQAAAAAw4AVBAAAAAIB4BEEAAAAAuJkBQQAAAADg\...\u002f0AAAAAAwHLwQAAAAAAge\u002fhAAAAAABDpBUEAAAAAkHH0QAAAAABIvgZBAAAAAPBy8EAAAAAA4Nb\u002fQAAAAACge\u002fhAAAAAAKDX\u002f0AAAAAAQHL0QAAAAACQcvRAAAAAAICqAkEAAAAAYJgBQQAAAADI6QVBAAAAAOBc60AAAAAA0Lv7QAAAAACwu\u002ftAAAAAAKiYAUEAAAAAUJgBQQAAAABIqgJBAAAAAEBy8EAAAAAAGDwFQQAAAACIqgJBAAAAAPA7BUEAAAAAoJgBQQAAAABgqgJBAAAAAOBZ60AAAAAAWJgBQQAAAABQ1v9AAAAAAJCcA0EAAAAAwLz7QAAAAADwu\u002ftAAAAAALiFB0EAAAAAsLz7QAAAAAAo6QVBAAAAAGBy8EAAAAAAIOkFQQAAAABgcfRAAAAAAJicA0EAAAAAuJwDQQAAAADAevhAAAAAALCFB0EAAAAA8JwDQQAAAACQcfRAAAAAAEiqAkEAAAAA4HLwQAAAAACgWutAAAAAAMCFBEEAAAAAoHH0QAAAAAAA6QVBAAAAAAB7+EAAAAAAUNf\u002fQAAAAABQqgJBAAAAABjpBUEAAAAA0IUHQQAAAADA1v9AAAAAALBx9EAAAAAA8Lv7QAAAAAA4vgZBAAAAANBy8EAAAAAA+DsFQQAAAABYmAFBAAAAAECqAkEAAAAAoNb\u002fQAAAAADAhQdBAAAAAAjpBUEAAAAA+DsFQQAAAADQe\...\...\u002fJZAAAAAAIBD4kAAAAAAYJ\u002fiQAAAAABgr+JAAAAAAEBD4kAAAAAAAI3iQAAAAABgQ+JAAAAAAADgsUAAAAAAACuxQAAAAAAAK7FAAAAAAADMsUAAAAAAAPyxQAAAAAAAnbFAAAAAAADosUAAAAAAAJ2xQAAAAAAA87FAAAAAAAABskAAAAAAwG3SQAAAAAAAatJAAAAAAMBO0kAAAAAAgGzSQAAAAADATtJAAAAAAABt0kAAAAAAAGrSQAAAAABAbdJAAAAAACD\u002f6EAAAAAAwMHlQAAAAADgpudAAAAAACAS60AAAAAAABLrQAAAAADgOepAAAAAAIDB5UAAAAAAQP\u002foQAAAAAAgp+dAAAAAAKA56kAAAAAAIMLlQAAAAABgPONAAAAAACDN40AAAAAAgMbmQAAAAAAAO+VAAAAAAIA\u002f50AAAAAAQJTmQAAAAAAgT+ZAAAAAAKBP50AAAAAA4DrlQAAAAADAEudAAAAAAIDG5kAAAAAAwPzlQAAAAABg\u002fuZAAAAAAIAj50AAAAAAYP7mQAAAAAAAzeNAAAAAAKDM40AAAAAAYOjmQAAAAACg\...\u002fXQAAAAABAv9dAAAAAAADEpUAAAAAAABiiQAAAAABQXQhBAAAAAHAj\u002fEAAAAAAaKcGQQAAAADwUQdBAAAAAEBvCUEAAAAAyPAFQQAAAADoXAhBAAAAABAi\u002fEAAAAAAyPAFQQAAAADAIvxAAAAAAOhRB0EAAAAAACP8QAAAAACApwZBAAAAALDwBUEAAAAAIF0IQQAAAADA8AVBAAAAAOAh\u002fEAAAAAAGFIHQQAAAACYbwlBAAAAAPBcCEEAAAAAeLoEQQAAAAAQ5fFAAAAAANhvAkEAAAAAWF0IQQAAAACIbwlBAAAAAEhdCEEAAAAAcLoEQQAAAAAwI\\u002fy0AAAAAAgGDGQAAAAAAAr8tAAAAAAIAhy0AAAAAAAPLBQAAAAACA78dAAAAAAIBUy0AAAAAAgO\u002fHQAAAAAAAoMtAAAAAAIB2yUAAAAAAgCHLQAAAAACAYMZAAAAAAIDwwUAAAAAAgFTLQAAAAAAALbdAAAAAAICJy0AAAAAAgHbJQAAAAAAArspAAAAAAACvy0AAAAAAgInLQAAAAAAALbdAAAAAAEDJ\u002fUAAAAAAcLH9QAAAAABwyfZAAAAAALB\u002f+kAAAAAA4N\u002f9QAAAAADgJflAAAAAANB2\u002fEAAAAAA0D39QAAAAADQ3\u002f1AAAAAANB\u002f+kAAAAAAcPX8QAAAAAAg+\u002ftAAAAAALB2\u002fEAAAAAA4D39QAAAAACAsf1AAAAAADD7+0AAAAAAcGP7QAAAAADQlv1AAAAAALBx\...\\u002f2EAAAAAAwCTcQAAAAABA0dRAAAAAAABu0EAAAAAAAATbQAAAAACAI9pAAAAAAICP20AAAAAAwJncQAAAAAAAM8NAAAAAAEDX20AAAAAAgDvbQAAAAAAAmbdAAAAAAIBNwEAAAAAAAKq6QAAAAAAAGblAAAAAAADVvkAAAAAAAOi\u002fQAAAAAAAzrxAAAAAAAB+wEAAAAAAAMiiQAAAAAAA5qdAAAAAAADeo0AAAAAAAGimQAAAAAAAiqRAAAAAAADApUAAAAAAAAynQAAAAAAADqBAAAAAAACeoUAAAAAAACClQAAAAAAAfKdA ...

# %% [markdown]
# #### Results visualization (MSE and R^2 metrics)

# %%
for name, targets in results.items():
    print(f"\nValidation Results for model {name}:\n")
    for target, metrics in targets.items():
        print(f"{target} — MSE: {metrics['MSE']:.2f}, R^2: {metrics['R^2']:.4f}")
# Out:
# Validation Results for model Linear_Regression:
#
# video_view_count — MSE: 220067369319779.00, R^2: 0.5874
# video_like_count — MSE: 94812489802.34, R^2: 0.9218
#
# Validation Results for model Ridge:
#
# video_view_count — MSE: 219975338122107.88, R^2: 0.5875
# video_like_count — MSE: 94817511120.03, R^2: 0.9218
#
# Validation Results for model Lasso:
#
# video_view_count — MSE: 219859576257921.16, R^2: 0.5878
# video_like_count — MSE: 94841756119.72, R^2: 0.9218
#
# Validation Results for model Decision_Tree:
#
# video_view_count — MSE: 462869121291732.50, R^2: 0.1321
# video_like_count — MSE: 353415379979.87, R^2: 0.7086
#
# Validation Results for model Random_Forest:
#
# video_view_count — MSE: 434305780210382.31, R^2: 0.1857
# video_like_count — MSE: 448914757838.19, R^2: 0.6298
#
# Validation Results for model XGBoost:
#
# video_view_count — MSE: 442006682144723.19, R^2: 0.1712
# video_like_count — MSE: 412630223603.98, R^2: 0.6598

# %%
for name, targets in results_test.items():
    print(f"\nTest Results for model {name}:\n")
    for target, metrics in targets.items():
        print(f"{target} — MSE: {metrics['MSE']:.2f}, R^2: {metrics['R^2']:.4f}")
# Out:
# Test Results for model Linear_Regression:
#
# video_view_count — MSE: 204913013085667.66, R^2: 0.0079
# video_like_count — MSE: 90109435650.77, R^2: 0.4257
#
# Test Results for model Ridge:
#
# video_view_count — MSE: 152187488131724.31, R^2: 0.2632
# video_like_count — MSE: 71009355495.35, R^2: 0.5474
#
# Test Results for model Lasso:
#
# video_view_count — MSE: 119586250075047.30, R^2: 0.4210
# video_like_count — MSE: 61543212851.28, R^2: 0.6078
#
# Test Results for model Decision_Tree:
#
# video_view_count — MSE: 278077070901919.84, R^2: -0.3463
# video_like_count — MSE: 68356951988.16, R^2: 0.5643
#
# Test Results for model Random_Forest:
#
# video_view_count — MSE: 159092453641556.69, R^2: 0.2298
# video_like_count — MSE: 30681849900.07, R^2: 0.8045
#
# Test Results for model XGBoost:
#
# video_view_count — MSE: 134152469665445.97, R^2: 0.3505
# video_like_count — MSE: 29951198438.09, R^2: 0.8091

# %%
for metric in ["MSE", "R^2"]:
    for target in ["video_view_count", "video_like_count"]:
        values = [results[model][target][metric] for model in model_classes]
        fig = go.Figure(data=[
            go.Bar(x=list(model_classes.keys()), y=values)
        ])
        fig.update_layout(
            title=f"Validation {metric.upper()} Comparison for {target}",
            xaxis_title="Model",
            yaxis_title=metric.upper(),
            template="plotly_white"
        )
        fig.show()

        filename = f'figure_{100+n_target}.html'
        filepath = os.path.join('iframe_figures', filename)
        fig.write_html(filepath)

        n_target += 1
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="9991981a-fa07-40e0-b7c1-58031c312992" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9991981a-fa07-40e0-b7c1-58031c312992")) {                    Plotly.newPlot(                        "9991981a-fa07-40e0-b7c1-58031c312992",                        [{"x":["Linear_Regression","Ridge","Lasso","Decision_Tree","Random_Forest","XGBoost"],"y":[220067369319779.0,219975338122107.88,219859576257921.16,462869121291732.5,434305780210382.3,442006682144723.2],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scattermap":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermap"}],"scatterpolargl":[{"marke ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="60b3a2bc-3571-4d09-b479-56e60a59f08f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("60b3a2bc-3571-4d09-b479-56e60a59f08f")) {                    Plotly.newPlot(                        "60b3a2bc-3571-4d09-b479-56e60a59f08f",                        [{"x":["Linear_Regression","Ridge","Lasso","Decision_Tree","Random_Forest","XGBoost"],"y":[94812489802.34447,94817511120.02911,94841756119.72462,353415379979.86816,448914757838.1852,412630223603.97577],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scattermap":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermap"}],"scatterpolargl":[{"marke ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="50aaf932-9914-497b-9ca2-6db8a162bb03" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("50aaf932-9914-497b-9ca2-6db8a162bb03")) {                    Plotly.newPlot(                        "50aaf932-9914-497b-9ca2-6db8a162bb03",                        [{"x":["Linear_Regression","Ridge","Lasso","Decision_Tree","Random_Forest","XGBoost"],"y":[0.5873747589738274,0.5875473170192947,0.5877643699484016,0.13212266167891107,0.18567878649030356,0.17123963303198697],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scattermap":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermap"}],"scatterpolargl":[ ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="5216a6c2-b0f5-4052-9d59-e04d4ea0f78f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5216a6c2-b0f5-4052-9d59-e04d4ea0f78f")) {                    Plotly.newPlot(                        "5216a6c2-b0f5-4052-9d59-e04d4ea0f78f",                        [{"x":["Linear_Regression","Ridge","Lasso","Decision_Tree","Random_Forest","XGBoost"],"y":[0.921820601346268,0.9218164609255507,0.921796469260945,0.7085847873059118,0.6298390023535991,0.6597580886762442],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scattermap":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermap"}],"scatterpolargl":[{"mar ...

# %%
for metric in ["MSE", "R^2"]:
    for target in ["video_view_count", "video_like_count"]:
        values = [results_test[model][target][metric] for model in model_classes]
        fig = go.Figure(data=[
            go.Bar(x=list(model_classes.keys()), y=values)
        ])
        fig.update_layout(
            title=f"Test {metric.upper()} Comparison for {target}",
            xaxis_title="Model",
            yaxis_title=metric.upper(),
            template="plotly_white"
        )
        fig.show()

        filename = f'figure_{100+n_target}.html'
        filepath = os.path.join('iframe_figures', filename)
        fig.write_html(filepath)

        n_target += 1
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="a379a19b-5ad8-4ced-b62e-5fa1f66d73eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a379a19b-5ad8-4ced-b62e-5fa1f66d73eb")) {                    Plotly.newPlot(                        "a379a19b-5ad8-4ced-b62e-5fa1f66d73eb",                        [{"x":["Linear_Regression","Ridge","Lasso","Decision_Tree","Random_Forest","XGBoost"],"y":[204913013085667.66,152187488131724.3,119586250075047.3,278077070901919.84,159092453641556.7,134152469665445.97],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scattermap":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermap"}],"scatterpolargl":[{"mark ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="000d8778-0b55-48bd-94b2-fc4dff8521b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("000d8778-0b55-48bd-94b2-fc4dff8521b6")) {                    Plotly.newPlot(                        "000d8778-0b55-48bd-94b2-fc4dff8521b6",                        [{"x":["Linear_Regression","Ridge","Lasso","Decision_Tree","Random_Forest","XGBoost"],"y":[90109435650.76588,71009355495.35385,61543212851.27782,68356951988.16356,30681849900.06896,29951198438.09297],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scattermap":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermap"}],"scatterpolargl":[{"marker" ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="1c8ca689-0310-464f-b0f3-72338ace0295" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1c8ca689-0310-464f-b0f3-72338ace0295")) {                    Plotly.newPlot(                        "1c8ca689-0310-464f-b0f3-72338ace0295",                        [{"x":["Linear_Regression","Ridge","Lasso","Decision_Tree","Random_Forest","XGBoost"],"y":[0.00791053424925181,0.26318196428340423,0.42102135359022164,-0.34631436312579633,0.22975146887209996,0.350498780163393],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scattermap":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermap"}],"scatterpolargl" ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="523a5854-8a28-4a1b-b60f-c704551e9794" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("523a5854-8a28-4a1b-b60f-c704551e9794")) {                    Plotly.newPlot(                        "523a5854-8a28-4a1b-b60f-c704551e9794",                        [{"x":["Linear_Regression","Ridge","Lasso","Decision_Tree","Random_Forest","XGBoost"],"y":[0.4256996311764526,0.5474314231757428,0.6077626101659586,0.5643361601929844,0.8044533562268675,0.8091100650505756],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scattermap":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermap"}],"scatterpolargl":[{"m ...

# %% [markdown]
# #### Conclusions

# %% [markdown]
# Based on the validation results, the best models for predicting the number of likes (video_like_count) are the linear models—specifically Ridge and Lasso regression—which achieved high $R^2$ values around 0.92, indicating excellent predictive performance. For predicting the number of views (video_view_count), although all models showed moderate performance, the Lasso regression slightly outperformed others with an $R^2$ of 0.5821. Therefore, Ridge and Lasso are the most reliable models for predicting likes, while Lasso is the most suitable choice for estimating views during validation.
#
# Considering that the splitting of training, validation, and test data was done based on the videos’ publication date and the compatibility of Ridge and Lasso with the test dataset, the best model for predicting both the number of views and likes is Lasso, although XGBoost showed better performance with the test dataset. This is because, if we choose to use a regression model to predict views and likes per video, we will actually only be using the training and validation dataset. In this textbook, we use the test dataset only to help us choose between Ridge and Lasso.
